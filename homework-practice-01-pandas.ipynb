# %% [markdown]
# ## Машинное обучение 1, ПМИ ФКН ВШЭ
#
# ## Практическое домашнее задание 1
#
# ### Общая информация
#
# Дата выдачи: 11.09.2020
#
# Мягкий дедлайн: 04:59MSK 21.09.2020 (но лучше сдайте пораньше и успейте выспаться)
#
# Жесткий дедлайн: 23:59MSK 24.09.2020

# %% [markdown]
# ### О задании
#
# Задание состоит из двух разделов, посвященных работе с табличными данными с помощью библиотеки pandas и визуализации с помощью matplotlib. В первом разделе вам предстоит выполнить базовые задания с помощью вышеуказанных библиотек, а во втором распределить студентов по курсам. Баллы даются за выполнение отдельных пунктов. Задачи в рамках одного раздела рекомендуется решать в том порядке, в котором они даны в задании.
#
# Задание направлено на освоение jupyter notebook (будет использоваться в дальнейших заданиях), библиотек pandas и matplotlib.
#
# ### Оценивание и штрафы
# Каждая из задач имеет определенную «стоимость» (указана в скобках около задачи). Максимально допустимая оценка за работу — 10 баллов.
#
# Сдавать задание после жёсткого дедлайна нельзя. При выставлении неполного балла за задание в связи с наличием ошибок на усмотрение проверяющего предусмотрена возможность исправить работу на указанных в ответном письме условиях.
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов (подробнее о плагиате см. на странице курса). Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник (скорее всего вы будете не единственным, кто это нашел, поэтому чтобы исключить подозрение в плагиате, необходима ссылка на источник).
#
# ### Формат сдачи
# Задания сдаются через систему Anytask. Инвайт можно получить у семинариста или ассистента. Присылать необходимо ноутбук с выполненным заданием. Сам ноутбук называйте в формате homework-practice-01-pandas-Username.ipynb, где Username — ваша фамилия.
#
# Для удобства проверки самостоятельно посчитайте свою максимальную оценку (исходя из набора решенных задач) и укажите ниже.
#
# Оценка: xx.

# %% [markdown]
# ## 0. Введение

# %% [markdown]
# Сейчас мы находимся в jupyter-ноутбуке (или ipython-ноутбуке). Это удобная среда для написания кода, проведения экспериментов, изучения данных, построения визуализаций и других нужд, не связанных с написанием production-кода.
#
# Ноутбук состоит из ячеек, каждая из которых может быть либо ячейкой с кодом, либо ячейкой с текстом размеченным и неразмеченным. Текст поддерживает markdown-разметку и формулы в Latex.
#
# Для работы с содержимым ячейки используется *режим редактирования* (*Edit mode*, включается нажатием клавиши **Enter** после выбора ячейки), а для навигации между ячейками искользуется *командный режим* (*Command mode*, включается нажатием клавиши **Esc**). Тип ячейки можно задать в командном режиме либо с помощью горячих клавиш (**y** to code, **m** to markdown, **r** to edit raw text), либо в меню *Cell -> Cell type*.
#
# После заполнения ячейки нужно нажать *Shift + Enter*, эта команда обработает содержимое ячейки: проинтерпретирует код или сверстает размеченный текст.

# %%
# ячейка с кодом, при выполнении которой появится output
2 + 2
# Out:
# 4

# %% [markdown]
# Ячейка с неразмеченыным текстом.

# %% [markdown]
# Попробуйте создать свои ячейки, написать какой-нибудь код и текст какой-нибудь формулой.

# %%
# your code
2**3
# Out:
# 8

# %% [markdown]
# [Здесь](https://athena.brynmawr.edu/jupyter/hub/dblank/public/Jupyter%20Notebook%20Users%20Manual.ipynb) находится <s>не</s>большая заметка о используемом языке разметки Markdown. Он позволяет:
#
# 0. Составлять упорядоченные списки
# 1. Выделять *текст* <s>при</s> **необходимости**
# 2. Добавлять [ссылки](http://imgs.xkcd.com/comics/the_universal_label.png)
#
#
# * Составлять неупорядоченные списки
#
# Делать вставки с помощью LaTex:
#
# $
# \left\{
# \begin{array}{ll}
# x = 16 \sin^3 (t) \\
# y = 13 \cos (t) - 5 \cos (2t) - 2 \cos (3t) - \cos (4t) \\
# t \in [0, 2 \pi]
# \end{array}
# \right.$

# %% [markdown]
# А ещё можно вставлять картинки, или гифки, или что захотите:
#
# <img src="https://media1.tenor.com/images/9b8fbe9214504bcf6c60fe4e4f7e114e/tenor.gif?itemid=5416416" style="width: 400px">

# %% [markdown]
# ### Google Colab

# %% [markdown]
# Что за колаб?
#
# **Google Colab (Colaboratory)** это **Jupyter Notebook + Cloud + Google Drive.**
#
# Компания Google предоставляет возможность бесплатно запускать ноутбуки (предварительно загрузив их на свой гугл-диск) прямо в облаке. При этом вам не требуется установка никаких пакетов на свою машину, а работать можно прямиком из браузера. Вот ссылка:

# %% [markdown]
# https://colab.research.google.com

# %% [markdown]
# При использовании вы увидете много сходств с jupyter ноутбуком. Одним из преимуществ является доступность GPU, соответствующую опцию можно активировать в настройках сервиса. При желании вы сможете найти в интернете много туториалов по использованию или разобраться самостоятельно =)

# %% [markdown]
# ## 1. Табличные данные и Pandas

# %% [markdown]
# Pandas — удобная библиотека для работы с табличными данными в Python, если данных не слишком много и они помещаются в оперативную память вашего компьютера. Несмотря на неэффективность реализации и некоторые проблемы, библиотека стала стандартом в анализе данных.
#
# Основной объект в pandas — это DataFrame, представляющий собой таблицу с именованными колонками различных типов, индексом (может быть многоуровневым). DataFrame можно создавать, считывая таблицу из файла или задавая вручную из других объектов.
#
# В этой части потребуется выполнить несколько небольших заданий. Можно пойти двумя путями: сначала изучить материалы, а потом приступить к заданиям, или же разбираться "по ходу". Выбирайте сами.
#
# Материалы:
# 1. [Pandas за 10 минут из официального руководства](http://pandas.pydata.org/pandas-docs/stable/10min.html)
# 2. [Документация](http://pandas.pydata.org/pandas-docs/stable/index.html) (стоит обращаться, если не понятно, как вызывать конкретный метод)
# 3. [Примеры использования функционала](http://nbviewer.jupyter.org/github/justmarkham/pandas-videos/blob/master/pandas.ipynb)
#
# Многие из заданий можно выполнить несколькими способами. Не существуют единственно верного, но попробуйте максимально задействовать арсенал pandas и ориентируйтесь на простоту и понятность вашего кода. Мы не будем подсказывать, что нужно использовать для решения конкретной задачи, попробуйте находить необходимый функционал сами (название метода чаще всего очевидно). В помощь вам документация, поиск и stackoverflow.

# %%
# %pylab inline  
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Скачаем данные:

# %%
# !wget  -O 'end_seminar.xlsx' -q 'https://www.dropbox.com/s/f4rm8sjc3v99p0m/_end_seminar.xlsx?dl=0'

# %% [markdown]
# Для пользователей Windows: скачайте файл самостоятельно и поместите его в папку с тетрадкой. Или попробуйте один из следующих вариантов:

# %%
# !powershell iwr -outf somefile https://somesite/somefile

# %%
# !pip install wget
# import wget 
# wget.download('https://dropbox.com/s/f4rm8sjc3v99p0m/_end_seminar.xlsx?dl=1', 'end_seminar.xlsx')

# %% [markdown]
# ##### В первой части задания (до раздела "Распределение студентов по курсам") использование циклов запрещается и повлечет за собой снижение оценки

# %% [markdown]
# Для каждой задачи из этого раздела вы должны написать код для получения ответа, а также дать текстовый ответ, если он предполагается.
#
# На некоторые вопросы вы можете получить путём пристального взгляда на таблицу, но это не будет засчитываться. Вы в любом случае должны получить ответ с помощью кода.

# %% [markdown]
# #### 1. [0 баллов] Откройте файл с таблицей (не забудьте про её формат). Выведите последние 10 строк.
#
# Посмотрите на данные и скажите, что они из себя представляют, сколько в таблице строк, какие столбцы? (на это не надо отвечать, просто подумайте об этом)

# %%
# your code
end_seminar = pd.read_excel('end_seminar.xlsx')
end_seminar.tail(10)
# Out:
#                   timestamp  ... is_ml_student
# 351 2020-05-18 23:58:33.903  ...           NaN
# 352 2020-05-18 23:59:20.831  ...           NaN
# 353 2020-05-18 23:59:28.998  ...           NaN
# 354 2020-05-19 08:55:39.509  ...           NaN
# 355 2020-05-19 18:58:06.283  ...           NaN
# 356 2020-05-19 19:04:17.873  ...           NaN
# 357 2020-05-19 20:19:25.815  ...           NaN
# 358 2020-05-20 11:54:38.318  ...           NaN
# 359 2020-05-23 21:16:40.916  ...           NaN
# 360 2020-05-23 21:16:40.916  ...           NaN
#
# [10 rows x 16 columns]

# %% [markdown]
# #### 2. [0.5 балла] Ответьте на вопросы:
# 1. Сколько было заявок из групп 18-го года набора, а сколько из групп 17-го года?
# 2. Есть ли студенты с равными перцентилями?

# %%
end_seminar.shape
# Out:
# (361, 16)

# %%
# your code
end_seminar.shape[0] - end_seminar['18_group'].isnull().sum(), \
end_seminar.shape[0] - end_seminar['17_group'].isnull().sum()
# Out:
# (223, 138)

# %%
end_seminar['percentile'].nunique()
# Да, есть т.к. количество уникальных строк меньше, чем общее кол-во. Также столбец не содержит пропусков.
# Out:
# 346

# %% [markdown]
# #### 3. [0.5 балла] Есть ли в данных пропуски? В каких колонках? Сколько их в каждой из этих колонок?

# %%
# your code
end_seminar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 361 entries, 0 to 360
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   timestamp      361 non-null    datetime64[ns]
#  1   id             361 non-null    object
#  2   rating         361 non-null    int64
#  3   18_group       223 non-null    float64
#  4   is_mi          18 non-null     float64
#  5   fall_1         361 non-null    object
#  6   fall_2         361 non-null    object
#  7   fall_3         361 non-null    object
#  8   spring_1       361 non-null    object
#  9   spring_2       361 non-null    object
#  10  spring_3       361 non-null    object
#  11  is_first_time  359 non-null    object
#  12  percentile     361 non-null    float64
#  13  17_group       138 non-null    float64
#  14  blended        138 non-null    object
#  15  is_ml_student  57 non-null     float64
# dtypes: datetime64[ns](1), float64(5), int64(1), object(9)
# ...

# %% [markdown]
# Заполните пропуски пустой строкой для строковых колонок и нулём для числовых.

# %%
# your code
columns_object = end_seminar.loc[:, end_seminar.dtypes ==  object].columns
end_seminar[columns_object] = end_seminar[columns_object].fillna('')

columns_float = end_seminar.loc[:, end_seminar.dtypes == float].columns
end_seminar[columns_float] = end_seminar[columns_float].fillna(0)

# %%
end_seminar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 361 entries, 0 to 360
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   timestamp      361 non-null    datetime64[ns]
#  1   id             361 non-null    object
#  2   rating         361 non-null    int64
#  3   18_group       361 non-null    float64
#  4   is_mi          361 non-null    float64
#  5   fall_1         361 non-null    object
#  6   fall_2         361 non-null    object
#  7   fall_3         361 non-null    object
#  8   spring_1       361 non-null    object
#  9   spring_2       361 non-null    object
#  10  spring_3       361 non-null    object
#  11  is_first_time  361 non-null    object
#  12  percentile     361 non-null    float64
#  13  17_group       361 non-null    float64
#  14  blended        361 non-null    object
#  15  is_ml_student  361 non-null    float64
# dtypes: datetime64[ns](1), float64(5), int64(1), object(9)
# ...

# %% [markdown]
# #### 4. [0.5 балла] Посмотрите повнимательнее на колонку 'is_first_time'.
#
# Есть ли в ней ответы "Нет"? Сколько их?
#
# Если вы найдете повторные обращения студентов, оставьте только самую позднюю версию.

# %%
# your code
end_seminar['is_first_time'][end_seminar['is_first_time']=='Нет'].count()
# Out:
# 51

# %% [markdown]
# #### 5. [0.5 балла] Какие  blended-курсы для четверокурсников существуют? На какой blended-курс записалось наибольшее количество студентов? На каком из курсов собрались студенты с самым высоким средним рейтингом?

# %%
# your code
end_seminar['blended'].unique()
# Out:
# array(['', 'DevOps', 'Введение в дифференциальную геометрию',
#        'Соревновательный анализ данных'], dtype=object)

# %%
end_seminar.groupby('blended').count()
# Out:
#                                        timestamp   id  ...  17_group  is_ml_student
# blended                                                ...
#                                              223  223  ...       223            223
# DevOps                                        91   91  ...        91             91
# Введение в дифференциальную геометрию         15   15  ...        15             15
# Соревновательный анализ данных                32   32  ...        32             32
#
# [4 rows x 15 columns]

# %%
end_seminar.groupby('blended').mean('rating')
# Out:
#                                             rating  ...  is_ml_student
# blended                                             ...
#                                         632.914798  ...       0.255605
# DevOps                                 1152.989011  ...       0.000000
# Введение в дифференциальную геометрию  1210.733333  ...       0.000000
# Соревновательный анализ данных         1144.218750  ...       0.000000
#
# [4 rows x 6 columns]

# %% [markdown]
# #### 6. [1 балл] Выясните, есть ли в данных студенты с абсолютно одинаковыми предпочтениями по всем курсам (не забудьте учесть blended-курсы для четверокурсников). Сколько таких наборов, которые взяли несколько студентов? Выведите их все вместе с количеством выбравших их студентов.

# %%
# your code
end_seminar_similar = end_seminar.groupby(['fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3', 'blended']).count().sort_values('timestamp', ascending=False)
end_seminar_similar.rename(columns={'timestamp': 'count_students'}, inplace=True)
end_seminar_similar[end_seminar_similar['count_students']>1][['count_students']]
# Out:
#                                                                                                                                                                                                                                                                                                     count_students
# fall_1                                          fall_2                                          fall_3                                          spring_1                                           spring_2                                    spring_3                                    blended
# Байесовские методы машинного обучения           Анализ неструктурированных данных               Глубинное обучение в обработке звука            Обучение с подкреплением                           Генеративные модели в машинном обучении     Компьютерное зрение                         DevOps                3
# ...

# %%
end_seminar_similar[end_seminar_similar['count_students']>1].shape[0]
# Out:
# 15

# %% [markdown]
# #### 7. [0.5 балла] Найдите курсы по выбору, на которые записывались как студенты 18-го года набора, так и студенты 17-го года.

# %%
end_seminar[~end_seminar['fall_1'].groupby(end_seminar['fall_1']).transform('count').gt(2)]
# Out:
# Empty DataFrame
# Columns: [timestamp, id, rating, 18_group, is_mi, fall_1, fall_2, fall_3, spring_1, spring_2, spring_3, is_first_time, percentile, 17_group, blended, is_ml_student]
# Index: []

# %%
df_17 = end_seminar[end_seminar['17_group']!=0] #заявки 17 года
df_18 = end_seminar[end_seminar['18_group']!=0] #заявки 18 года

# %%
# Список курсов предлагаемых 17 и 18 году осенью
df_fall_course = pd.concat([pd.DataFrame(df_18['fall_1'].unique()), pd.DataFrame(df_17['fall_1'].unique())])
df_fall_course[df_fall_course[0].duplicated()]
# Out:
#                                                    0
# 0                   Безопасность компьютерных систем
# 2                  Высокопроизводительные вычисления
# 3                        Statistical Learning Theory
# 6                      Моделирование временных рядов
# 7    Сбор и обработка данных с помощью краудсорсинга
# 8  Принятие решений в условиях риска и неопределё...

# %%
# Список курсов предлагаемых 17 и 18 году весной
df_spring_course = pd.concat([pd.DataFrame(df_18['spring_1'].unique()), pd.DataFrame(df_17['spring_1'].unique())])
df_spring_course[df_spring_course[0].duplicated()]
# Out:
#                   0
# 7  Численные методы

# %% [markdown]
# Методом исключения найдите курсы, которые предлагались только студентам 18-го года и только студентам 17-го года.

# %%
pd.DataFrame(df_18['fall_1'].unique()) # список курсов 18 года осень
df_fall_course[df_fall_course[0].duplicated(keep=False)==False] # Список курсов предлагаемых 17 и 18 году поотдельности осенью
# Out:
#                                        0
# 0                               Язык SQL
# 4                      Теория баз данных
# 7                   Матричные вычисления
# 1   Глубинное обучение в обработке звука
# 4      Анализ неструктурированных данных
# 5  Байесовские методы машинного обучения

# %%
# Список курсов предлагаемых только 18 году осенью
df_fall_tmp = pd.concat([df_fall_course[df_fall_course[0].duplicated(keep=False)==False], pd.DataFrame(df_18['fall_1'].unique())])
df_fall_tmp[df_fall_tmp[0].duplicated()]
# Out:
#                       0
# 0              Язык SQL
# 4     Теория баз данных
# 7  Матричные вычисления

# %%
# Список курсов предлагаемых только 17 году осенью
df_fall_tmp = pd.concat([df_fall_course[df_fall_course[0].duplicated(keep=False)==False], pd.DataFrame(df_17['fall_1'].unique())])
df_fall_tmp[df_fall_tmp[0].duplicated()]
# Out:
#                                        0
# 1   Глубинное обучение в обработке звука
# 4      Анализ неструктурированных данных
# 5  Байесовские методы машинного обучения

# %%
# Список курсов предлагаемых только 18 году весной
df_spring_tmp = pd.concat([df_spring_course[df_spring_course[0].duplicated(keep=False)==False], pd.DataFrame(df_18['spring_1'].unique())])
df_spring_tmp[df_spring_tmp[0].duplicated()]
# Out:
#                                              0
# 0                       Дискретная оптимизация
# 1                            Компьютерные сети
# 2  Промышленное программирование на языке Java
# 4   Дополнительные главы прикладной статистики
# 5                      Анализ данных в бизнесе
# 6                          Машинное обучение 2
# 7                           Системы баз данных

# %%
# Список курсов предлагаемых только 17 году весной
df_spring_tmp = pd.concat([df_spring_course[df_spring_course[0].duplicated(keep=False)==False], pd.DataFrame(df_17['spring_1'].unique())])
df_spring_tmp[df_spring_tmp[0].duplicated()]
# Out:
#                                                    0
# 0                                Компьютерное зрение
# 1  Проектирование и разработка высоконагруженных ...
# 2                             Конфликты и кооперация
# 3                              Символьные вычисления
# 4               Методы сжатия и передачи медиаданных
# 5                           Обучение с подкреплением
# 6            Генеративные модели в машинном обучении

# %% [markdown]
# ### Визуализации и matplotlib

# %% [markdown]
# При работе с данными часто неудобно делать какие-то выводы, если смотреть на таблицу и числа в частности, поэтому важно уметь визуализировать данные. Здесь будут описаны ключевые правила оформления графиков для **всех** домашних заданий.
#
# У matplotlib, конечно же, есть [документация](https://matplotlib.org/users/index.html) с большим количеством [примеров](https://matplotlib.org/examples/), но для начала достаточно знать про несколько основных типов графиков:
# - plot — обычный поточечный график, которым можно изображать кривые или отдельные точки;
# - hist — гистограмма, показывающая распределение некоторой величины;
# - scatter — график, показывающий взаимосвязь двух величин;
# - bar — столбцовый график, показывающий взаимосвязь количественной величины от категориальной.
#
# В этом задании вы попробуете построить один из них. Не забывайте про базовые принципы построения приличных графиков:
# - оси должны быть подписаны, причём не слишком мелко;
# - у графика должно быть название;
# - если изображено несколько графиков, то необходима поясняющая легенда;
# - все линии на графиках должны быть чётко видны (нет похожих цветов или цветов, сливающихся с фоном);
# - если отображена величина, имеющая очевидный диапазон значений (например, проценты могут быть от 0 до 100), то желательно масштабировать ось на весь диапазон значений (исключением является случай, когда вам необходимо показать малое отличие, которое незаметно в таких масштабах);
# - сетка на графике помогает оценить значения в точках на глаз, это обычно полезно, поэтому лучше ее отрисовывать;
# - если распределение на гистограмме имеет тяжёлые хвосты, лучше использовать логарифмическую шкалу.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# #### 8. [0.5 балла] Постройте график средних рейтингов по дням получения ответов (bar plot).

# %%
# your code
end_seminar['timestamp'] = pd.to_datetime(end_seminar['timestamp']).dt.strftime("%y/%m/%d")
end_seminar.head(3)
# Out:
#   timestamp                                id  ...  blended  is_ml_student
# 0  20/05/15  93ff79a51cd602f1dd3028ba2c129503  ...                     0.0
# 1  20/05/15  26b01b1c4cd5656bab18d24c548834fb  ...                     0.0
# 2  20/05/15  30f3653fc176d54e89ac3179c455c6dd  ...                     0.0
#
# [3 rows x 16 columns]

# %%
df_plot = end_seminar.groupby('timestamp').mean()
df_plot.reset_index(inplace=True)

# %%
plt.figure(figsize=(15,5))
plt.grid()
ax = plt.bar(df_plot['timestamp'], df_plot['rating'])
plt.title('Средние рейтинги по дням получения ответов')
plt.xlabel('Дни')
plt.xticks(rotation=0)
plt.ylabel('Средний рейтинг')
plt.show()

# %% [markdown]
# Сохраните график в формате pdf (так он останется векторизованным).

# %%
# https://habr.com/ru/post/544132/
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.pyplot as plt
import numpy as np

# Создание файла.
pdf = PdfPages("Figures.pdf")

# Создание сюжетов и их сохранение.
plt.figure(figsize=(15,5))
plt.grid()
ax = plt.bar(df_plot['timestamp'], df_plot['rating'])
plt.title('Средние рейтинги по дням получения ответов')
plt.xlabel('Дни')
plt.xticks(rotation=0)
plt.ylabel('Средний рейтинг')

pdf.savefig()
plt.close()

# Сохранение файла
pdf.close()

# %% [markdown]
# Еще одна билиотека для визуализации: [seaborn](https://jakevdp.github.io/PythonDataScienceHandbook/04.14-visualization-with-seaborn.html). Это настройка над matplotlib, иногда удобнее и красивее делать визуализации через неё.

# %% [markdown]
# ### 2. Распределение студентов по курсам.

# %% [markdown]
# Теперь вам нужно распределить студентов по осенним курсам по выбору, учитывая их предпочтения.

# %% [markdown]
# Алгоритм распределения студентов по курсам:
# 1. По умолчанию на каждой дисциплине по выбору у 3 и 4 курсов может учиться 1 группа (до 30 студентов). Исключения описаны ниже. На blended-дисциплинах для четверокурсников количество мест не ограничено.
# 2. Проводится первая волна отбора. Для каждой дисциплины формируется список тех, кто указал её первым приоритетом (если студент должен выбрать два курса по выбору, то для него дисциплины, которые он указал первым и вторым приоритетом, рассматриваются как дисциплины первого приоритета). Если желающих больше, чем мест, то выбирается топ по перцентилю рейтинга.
# 3. На дисциплинах, где остались места после первой волны, формируются списки тех, кто выбрал их вторым приоритетом, и места заполняются лучшими по перцентили рейтинга студентами. После этого проводится такая же процедура для дисциплин третьего приоритета.
# 4. Если студент не попал на необходимое количество курсов по итогам трёх волн, с ним связывается учебный офис и решает вопрос в индивидуальном порядке.

# %% [markdown]
# Обращаем ваше внимание на следующие детали:
#
# - По умолчанию студент выбирает один осенний и один весенний курс по выбору, а также четверокурсники выбирают один blended-курс. Студенты групп 17-го года специализаций МОП и ТИ выбирают по 2 осенних и 2 весенних курса по выбору, также студенты групп 18' специализации МИ выбирают 2 осенних курса.
#
# - Студенты специализации МОП не могут выбрать весенним курсом по выбору Машинное обучение 2.
#
# - Blended-курсы не трогайте, по ним не надо распределять, на другие курсы они никак не влияют.
#
# - Постарайтесь воздержаться от использования циклов там, где это возможно.
#
# - На выходе ожидается файл res_fall.csv с результатами распределения на осенние курсы по выбору. Файл должен быть следующего формата:
#
#     * три столбца: ID, course1, course2
#
#     * Если студент не попал на курс, но должен был, то вместо названия курса в ячейке должна быть строка "???"
#
#     * Если студент должен выбрать только один курс, то в колонке course2 для него должна стоять строка "-"
#
#     * Формат csv: для сохранения воспользуйтесь df.to_csv('solution.csv', index=None)
#
#
# Для работы вам могут понадобиться следующие данные:
#
# - Результаты опроса (вы уже использовали этот файл в первой части задания, но на всякий случай ссылка: https://www.dropbox.com/s/f4rm8sjc3v99p0m/_end_seminar.xlsx?dl=0)
#
# - Соответствие номеров групп специализациям:
#
#     * 171, 172 - МОП; 173 - ТИ; 174 — АДИС; 175, 176 — РС; 177 — АПР
#
#     * 181, 182 - МОП; 183 - ТИ; 184 - АДИС; 185, 186 - РС; 187 - АПР; 188 - МИ
#
# - Ограничения по количеству мест на курсах по выбору:
#
#     * Осенние: везде 30 мест, кроме Statistical Learning Theory (60 мест), Высокопроизводительных вычислений (60 мест), Анализа неструктурированных данных ($\infty$ мест)
#
#     * Весенние: везде 30 мест, кроме Обучения с подкреплением (60 мест), Анализа данных в бизнесе (60 мест).
#
#
# Кстати, убедитесь, что в данных больше нет пропусков и повторных записей.

# %% [markdown]
# #### 0. Проверка
#
# Для начала давайте убедимся, что вы успешно выполнили задания первой части и проверим ваши данные на наличие пропусков и повторов:

# %%
end_seminar['id'].nunique()
# Out:
# 347

# %%
# Проверим дубликаты
pd.concat([end_seminar, end_seminar.drop_duplicates('id')]).drop_duplicates(keep=False)
# Out:
#     timestamp                                id  ...  blended  is_ml_student
# 23   20/05/15  a65d50ef4fadfac64508a54e972d8623  ...                     0.0
# 30   20/05/16  b121e4d7d62387cd5199cca464a34a6d  ...                     0.0
# 98   20/05/18  5ee2ad618729a6dc3bdb7f2858826ef0  ...                     0.0
# 126  20/05/18  5c49473012411a1eee72f8ea63767adf  ...                     0.0
# 139  20/05/18  ffc58d371e2f52e1c7f45d49d3d629d0  ...                     1.0
# 150  20/05/18  f8fab519d78047712c06798c8b7fe38f  ...                     0.0
# 152  20/05/18  9015b809a29fb65ce23d7addf16d770d  ...                     0.0
# 176  20/05/18  8aa0f1b7331b49464174b02cd693be52  ...                     0.0
# 192  20/05/18  86c24daaa62246142d46ee58534a65e0  ...                     0.0
# 204  20/05/18  47e2d8bbb630bc2d9b3fbf98fe77cffb  ...                     0.0
# 259  20/05/17  906692ccd33f59058380aac1598c5480  ...   DevOps            0.0
# ...

# %%
end_seminar[end_seminar['id']=='5ee2ad618729a6dc3bdb7f2858826ef0']
# Out:
#    timestamp                                id  ...  blended  is_ml_student
# 97  20/05/18  5ee2ad618729a6dc3bdb7f2858826ef0  ...                     0.0
# 98  20/05/18  5ee2ad618729a6dc3bdb7f2858826ef0  ...                     0.0
#
# [2 rows x 16 columns]

# %%
# Дубликаты это заявления студентов поданные повторно, удаляем те которые поданы первыми. Графа is_first_time содержит 'Да'
end_seminar.drop_duplicates('id', keep='last', inplace=True)

# %%
assert end_seminar.shape[0] == 347, 'В таблице остались повторы или потеряны данные'

assert end_seminar.isna().sum().sum() == 0, 'В таблице остались пропуски'

# %% [markdown]
# Если вы не получили AssertionError, то можете продолжать.

# %% [markdown]
# #### 1. [1 балл] Создайте новый признак, обозначающий, сколько осенних курсов должен выбрать студент
#
# В этом вам может помочь информация о специализации и группе стундента.

# %%
def num_course_fall(df):
    if ((df['is_mi']!=0)&(df['18_group']!=0))|(df['17_group']==171)|(df['17_group']==172)|(df['17_group']==173):
        return 2
    return 1

# %%
# (￣^￣)ゞ
end_seminar['num_course_fall'] = end_seminar.apply(num_course_fall,axis=1)

# %% [markdown]
# Проверка:

# %%
col_name =  'num_course_fall'   # insert your new column name as str

assert (end_seminar[end_seminar['id'] == '2662600c2c37e11e62f6ee0b88452f22'][col_name] == 2).all()
assert (end_seminar[end_seminar['id'] == 'd555d2805e1d93d4f023e57dc4c8f403'][col_name] == 2).all()
assert (end_seminar[end_seminar['id'] == '8fe79f84f36e3a5d2d6745621321302c'][col_name] == 1).all()
assert (end_seminar[end_seminar['id'] == 'e4caca755ee0bdd711e18fb8084958b5'][col_name] == 1).all()

# %% [markdown]
# #### 2. [2 балла] Распределите студентов в соответствии с первым приоритетом

# %%
def num_student_cour_fall(current_cour_str_fall, num_students_all):
    if (current_cour_str_fall=='Statistical Learning Theory')|(current_cour_str_fall=='Высокопроизводительные вычисления'):
        return 60
    elif current_cour_str_fall=='Анализ неструктурированных данных':
        return num_students_all
    return 30

# %%
# %%time
course_1 = dict()
course_2 = dict()
num_students_all = end_seminar['id'].shape[0]
for el in end_seminar['id']:
# Заполнение списка course_1
    # Имя курса строкой для текущего id
    current_fall_1_str = pd.DataFrame(end_seminar['fall_1'][end_seminar['id']==el]).iloc[0]['fall_1']
   
    # df_tmp для поиска вхождения текущего id в первую волну приоритета
    # df_tmp отфильтрован по fall_1 и (fall_2, где num_course_fall==2) и отсортирован по percentile
    # Убраны дубликаты при указании одного и того же курса в fall_1 и fall_2
    df_tmp = pd.concat([end_seminar.loc[end_seminar['fall_1']==current_fall_1_str], 
            end_seminar.loc[(end_seminar['fall_2']==current_fall_1_str)&(end_seminar['num_course_fall']==2)]]).drop_duplicates()\
            .sort_values('percentile').head(num_student_cour_fall(current_fall_1_str, num_students_all))
    
    if df_tmp.loc[df_tmp['id']==el].shape[0]==1:
        course_1[el] = current_fall_1_str
    else:
        course_1[el] = '???'
    
# Заполнение списка course_2
    if pd.DataFrame(end_seminar['num_course_fall'][end_seminar['id']==el]).iloc[0]['num_course_fall']==2:
        # Имя курса строкой для id текущего элемента цикла
        current_fall_2_str = pd.DataFrame(end_seminar['fall_2'][end_seminar['id']==el]).iloc[0]['fall_2']

        # df_tmp для поиска вхождения текущего id в первую волну приоритета
        # df_tmp отфильтрован по fall_1 и (fall_2, где num_course_fall==2) и отсортирован по percentile
        # Убраны дубликаты при указании одного и того же курса в fall_1 и fall_2
        df_tmp = pd.concat([end_seminar.loc[end_seminar['fall_1']==current_fall_2_str], 
                end_seminar.loc[(end_seminar['fall_2']==current_fall_2_str)&(end_seminar['num_course_fall']==2)]]).drop_duplicates()\
                .sort_values('percentile').head(num_student_cour_fall(current_fall_2_str, num_students_all))
        
        #если course_1 дубликат fall_2 ставим  в course_2 '???'
        if (df_tmp.loc[df_tmp['id']==el].shape[0]==1)&(course_1[el]!=current_fall_2_str):
            course_2[el] = current_fall_2_str
        else:
            course_2[el] = '???'
    else:
        course_2[el] = '-'
# Out:
# CPU times: user 4.78 s, sys: 30.9 ms, total: 4.81 s
# Wall time: 4.82 s

# %%
end_seminar = end_seminar.merge(pd.DataFrame.from_dict(course_1, orient='index', columns=['course_1']), how='left', left_on='id', right_index=True)
end_seminar = end_seminar.merge(pd.DataFrame.from_dict(course_2, orient='index', columns=['course_2']), how='left', left_on='id', right_index=True)
end_seminar.head()
# Out:
#   timestamp  ... course_2
# 0  20/05/15  ...        -
# 1  20/05/15  ...        -
# 2  20/05/15  ...        -
# 3  20/05/15  ...        -
# 4  20/05/15  ...        -
#
# [5 rows x 19 columns]

# %% [markdown]
# Здесь для проверки приведена таблица, в которой есть 2 дополнительные колонки:
#
#     1) is_first_place - является ли студент лучшим по перцентили хотя бы на одном из курсов, куда он был зачислен
#     (True / NaN)
#
#     2) is_last_place  - является ли студент худшим по перцентили хотя бы на одном из курсов, куда он был зачислен (True / NaN)

# %%
# !wget  -O '2_task_check.csv' -q 'https://www.dropbox.com/s/v8o2zzq3iz5gc9w/_2_task_check.csv?dl=0'
check_df = pd.read_csv('2_task_check.csv')

# %%
df_course_1 = end_seminar[['course_1', 'percentile']].groupby('course_1').agg([min, max]).drop(['???'])
df_course_2 = end_seminar[['course_2', 'percentile']].groupby('course_2').agg([min, max]).drop(['???', '-'])
df_min_max_percentile = df_course_1.merge(df_course_2, how='outer', left_index=True, right_index=True).T.agg([min, max]).T

# %%
is_first_place = df_min_max_percentile['min'].to_list()
end_seminar.loc[end_seminar['percentile'].isin(is_first_place),'is_first_place'] = 'True'

is_last_place = df_min_max_percentile['max'].to_list()
end_seminar.loc[end_seminar['percentile'].isin(is_last_place),'is_last_place'] = 'True'

# %% [markdown]
# После распределения студентов в соответствии с первым приоритетом добавьте в свой датафрейм аналогичные признаки и запустите проверку:

# %%
fir_col_name =   'is_first_place'    # insert name of your new column with is_first_place as str
last_col_name = 'is_last_place'     # insert name of your new column with is_last_place as str


assert ((end_seminar[end_seminar[fir_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True)
        ==
        check_df[check_df['is_first_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True)
       ).id.values).all()


assert ((end_seminar[end_seminar[last_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True)
       == 
       check_df[check_df['is_last_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True)
      ).id.values).all()

# %% [markdown]
# #### 3. [3 балла] Проведите все три волны отбора студентов на курсы по выбору

# %%
end_seminar.loc[(end_seminar['course_1']=='???')|(end_seminar['course_2']=='???')].shape
# Out:
# (105, 21)

# %%
# (￣^￣)ゞ
# Вторая волна
# Исхожу из логики - стобец fall_2 полностью используется для заполнения '???' и не важно 2 курса у студента или 1
# При уже заполненом курсом 2 у студента строка пропускается.
remain_students = end_seminar.loc[(end_seminar['course_1']=='???')&(end_seminar['num_course_fall']==1)\
                                  |(end_seminar['course_2']=='???')]            # таблица с незаполненными курсами
course_1 = dict()
course_2 = dict()

for el in remain_students['id']:
    # Имя курса №1 и №2 строкой для текущего id
    current_fall_1_str = pd.DataFrame(remain_students['fall_1'][remain_students['id']==el]).iloc[0]['fall_1']
    current_fall_2_str = pd.DataFrame(remain_students['fall_2'][remain_students['id']==el]).iloc[0]['fall_2']

    # количество оставшихся мест для зачисления на курс
    if end_seminar[end_seminar['course_1']==current_fall_2_str].groupby('course_1').count().empty:
        filled_course_1_fall = 0
    else:
        filled_course_1_fall = end_seminar[end_seminar['course_1']==current_fall_2_str].groupby('course_1').count().iloc[0]['id']
    if end_seminar[end_seminar['course_2']==current_fall_2_str].groupby('course_2').count().empty:
        filled_course_2_fall = 0
    else:
        filled_course_2_fall = end_seminar[end_seminar['course_2']==current_fall_2_str].groupby('course_2').count().iloc[0]['id']
    num = num_student_cour_fall(current_fall_2_str, num_students_all) - filled_course_1_fall - filled_course_2_fall

    if num >0:
        # df_tmp для поиска вхождения текущего id во вторрую волну
        # df_tmp отфильтрован по fall_2 и отсортирован по percentile
        # определено количество оставшихся мест на курсе
        # учтены те кто вписал в fall_1 и fall_2 одно и тоже, у них с 1 волны стоит '???' в course_2 
        df_tmp = pd.concat([remain_students.loc[remain_students['fall_2']==current_fall_2_str],\
        remain_students[((remain_students['fall_2']==remain_students['course_1']))\
        &(remain_students['fall_2']==current_fall_2_str)]]).drop_duplicates(keep=False).sort_values('percentile').head(num)

        if df_tmp.loc[df_tmp['id']==el].shape[0]==1: # Если теккущий id входит в df_tmp
            if pd.DataFrame(remain_students['num_course_fall'][remain_students['id']==el]).iloc[0]['num_course_fall']==2:
                course_2[el] = current_fall_2_str
            else: # num_course_fall==1
                course_1[el] = current_fall_2_str

# %%
for k, v in course_1.items():
    end_seminar.loc[end_seminar['id']==k, 'course_1'] = v
for k, v in course_2.items():
    end_seminar.loc[end_seminar['id']==k, 'course_2'] = v

# %%
end_seminar.loc[(end_seminar['course_1']=='???')|(end_seminar['course_2']=='???')].shape
# Out:
# (68, 21)

# %%
# Третья волна
# Исхожу из логики - стобец fall_3 полностью используется для заполнения '???'

remain_students = end_seminar.loc[(end_seminar['course_1']=='???')\
                                  |(end_seminar['course_2']=='???')]# таблица с незаполненными курсами
course_1 = dict()
course_2 = dict()

for el in remain_students['id']:
    # Имя курса №3 строкой для текущего id
    current_fall_3_str = pd.DataFrame(remain_students['fall_3'][remain_students['id']==el]).iloc[0]['fall_3']

    # количество оставшихся мест для зачисления на курс
    if end_seminar[end_seminar['course_1']==current_fall_3_str].groupby('course_1').count().empty:
        filled_course_1_fall = 0
    else:
        filled_course_1_fall = end_seminar[end_seminar['course_1']==current_fall_3_str].groupby('course_1').count().iloc[0]['id']
    if end_seminar[end_seminar['course_2']==current_fall_3_str].groupby('course_2').count().empty:
        filled_course_2_fall = 0
    else:
        filled_course_2_fall = end_seminar[end_seminar['course_2']==current_fall_3_str].groupby('course_2').count().iloc[0]['id']
    num = num_student_cour_fall(current_fall_3_str, num_students_all) - filled_course_1_fall - filled_course_2_fall

    if num >0:
        # df_tmp для поиска вхождения текущего id в третью волну
        # df_tmp отфильтрован по fall_3 и отсортирован по percentile
        # определено количество оставшихся мест на курсе
        # учтены те, кто вписал в fall_1, fall_2 и/или fall_3 одинаковые курсы, у них с 1 волны стоит '???' в course_2 если fall_1==fall_2
        # если fall_3 уже вписан в course_1|course_2 его удалить из рассмотрения
        df_tmp = pd.concat([remain_students.loc[remain_students['fall_3']==current_fall_3_str],\
        remain_students[((remain_students['fall_3']==remain_students['course_1'])|(remain_students['fall_3']==remain_students['course_2']))\
        &(remain_students['fall_3']==current_fall_3_str)]]).drop_duplicates(keep=False).sort_values('percentile').head(num)

        if df_tmp.loc[df_tmp['id']==el].shape[0]==1:
            if pd.DataFrame(remain_students['num_course_fall'][remain_students['id']==el]).iloc[0]['num_course_fall']==2:
                if pd.DataFrame(remain_students['course_1'][remain_students['id']==el]).iloc[0]['course_1']=='???':
                    course_1[el] = current_fall_3_str
                else:
                    course_2[el] = current_fall_3_str
            else: # num_course_fall==1
                course_1[el] = current_fall_3_str

# %%
for k, v in course_1.items():
    end_seminar.loc[end_seminar['id']==k, 'course_1'] = v
for k, v in course_2.items():
    end_seminar.loc[end_seminar['id']==k, 'course_2'] = v

# %%
end_seminar.loc[(end_seminar['course_1']=='???')|(end_seminar['course_2']=='???')].shape
# Out:
# (36, 21)

# %%
end_seminar[['id', 'course_1', 'course_2']].to_csv('res_fall.csv', index=None)

# %% [markdown]
# **Отправьте свой файл res_fall.csv в контест (https://contest.yandex.ru/contest/19782/problems/A/) и прикрепите/укажите ниже ваш никнейм и ссылку на успешную посылку.**

# %% [markdown]
# *Дисклеймер:*
#
# Контест выдаётся для самопроверки. Если ваша посылка получила ОК, то код, скорее всего, правильный. Но при этом оценка всё равно может быть снижена в случае обнаружения неэффективностей или ошибок в коде. Если вы сдадите в AnyTask очевидно неработающий код или ноутбук без кода, но при этом в контест будет сдан корректный файл, то это будет расцениваться как плагиат.

# %% [markdown]
# На всякий случай просим вас сдать вместе с ноутбуком файл res_fall.csv в anytask

# %% [markdown]
# **Дополнительное задание. [2 бонусных балла] Распределите таким же образом студентов еще и на весенние курсы по выбору.**
#
# Если ваш код был хорошо структурирован, то это не составит проблем.
#
# Если вы выполнили это задание, сдайте среди прочего файл res_spring.csv в таком же формате, как и res_fall.csv.

# %%
# (￣^'￣)ゞ

# %%
def num_course_spring(df):
    if (df['17_group']==171)|(df['17_group']==172)|(df['17_group']==173):
        return 2
    return 1

# %%
# (￣^￣)ゞ
end_seminar['num_course_spring'] = end_seminar.apply(num_course_spring,axis=1)

# %%
def num_student_cour_spring(current_cour_str_spring):
    if (current_cour_str_spring=='Обучение с подкреплением')|(current_cour_str_spring=='Анализ данных в бизнесе'):
        return 60
    return 30

# %%
# %%time
course_1 = dict()
course_2 = dict()
for el in end_seminar['id']:
# Заполнение списка course_1
    # Имя курса строкой для текущего id
    current_spring_1_str = pd.DataFrame(end_seminar['spring_1'][end_seminar['id']==el]).iloc[0]['spring_1']
   
    # df_tmp для поиска вхождения текущего id в первую волну приоритета
    # df_tmp отфильтрован по spring_1 и (spring_2, где num_course_spring==2) и отсортирован по percentile
    # Убраны дубликаты при указании одного и того же курса в spring_1 и spring_2
    df_tmp = pd.concat([end_seminar.loc[end_seminar['spring_1']==current_spring_1_str], 
            end_seminar.loc[(end_seminar['spring_2']==current_spring_1_str)&(end_seminar['num_course_spring']==2)]]).drop_duplicates()\
            .sort_values('percentile').head(num_student_cour_spring(current_spring_1_str))
    
    if df_tmp.loc[df_tmp['id']==el].shape[0]==1:
        course_1[el] = current_spring_1_str
    else:
        course_1[el] = '???'
    
# Заполнение списка course_2
    if pd.DataFrame(end_seminar['num_course_spring'][end_seminar['id']==el]).iloc[0]['num_course_spring']==2:
        # Имя курса строкой для id текущего элемента цикла
        current_spring_2_str = pd.DataFrame(end_seminar['spring_2'][end_seminar['id']==el]).iloc[0]['spring_2']

        # df_tmp для поиска вхождения текущего id в первую волну приоритета
        # df_tmp отфильтрован по spring_1 и (spring_2, где num_course_spring==2) и отсортирован по percentile
        # Убраны дубликаты при указании одного и того же курса в spring_1 и spring_2
        df_tmp = pd.concat([end_seminar.loc[end_seminar['spring_1']==current_spring_2_str], 
                end_seminar.loc[(end_seminar['spring_2']==current_spring_2_str)&(end_seminar['num_course_spring']==2)]]).drop_duplicates()\
                .sort_values('percentile').head(num_student_cour_spring(current_spring_2_str))
        
        #если course_1_spring дубликат spring_2 ставим  в course_2_spring '???'
        if (df_tmp.loc[df_tmp['id']==el].shape[0]==1)&(course_1[el]!=current_spring_2_str):
            course_2[el] = current_spring_2_str
        else:
            course_2[el] = '???'
    else:
        course_2[el] = '-'
# Out:
# CPU times: user 4.89 s, sys: 24.5 ms, total: 4.92 s
# Wall time: 4.91 s

# %%
end_seminar = end_seminar.merge(pd.DataFrame.from_dict(course_1, orient='index', columns=['course_1_spring']), how='left', left_on='id', right_index=True)
end_seminar = end_seminar.merge(pd.DataFrame.from_dict(course_2, orient='index', columns=['course_2_spring']), how='left', left_on='id', right_index=True)
end_seminar.head()
# Out:
#   timestamp  ... course_2_spring
# 0  20/05/15  ...               -
# 1  20/05/15  ...               -
# 2  20/05/15  ...               -
# 3  20/05/15  ...               -
# 4  20/05/15  ...               -
#
# [5 rows x 24 columns]

# %%
end_seminar.loc[(end_seminar['course_1_spring']=='???')|(end_seminar['course_2_spring']=='???')].shape
# Out:
# (69, 24)

# %%
# (￣^￣)ゞ
# Вторая волна
# Исхожу из логики - стобец fall_2 полностью используется для заполнения '???' и не важно 2 курса у студента или 1
# При уже заполненом курсом 2 у студента строка пропускается.
remain_students = end_seminar.loc[(end_seminar['course_1_spring']=='???')&(end_seminar['num_course_spring']==1)\
                                  |(end_seminar['course_2_spring']=='???')]            # таблица с незаполненными курсами
course_1 = dict()
course_2 = dict()

for el in remain_students['id']:
    # Имя курса №1 и №2 строкой для текущего id
    current_spring_1_str = pd.DataFrame(remain_students['spring_1'][remain_students['id']==el]).iloc[0]['spring_1']
    current_spring_2_str = pd.DataFrame(remain_students['spring_2'][remain_students['id']==el]).iloc[0]['spring_2']

    # количество оставшихся мест для зачисления на курс
    if end_seminar[end_seminar['course_1_spring']==current_spring_2_str].groupby('course_1_spring').count().empty:
        filled_course_1_spring = 0
    else:
        filled_course_1_spring = end_seminar[end_seminar['course_1_spring']==current_spring_2_str].groupby('course_1_spring').count().iloc[0]['id'] 
    if end_seminar[end_seminar['course_2_spring']==current_spring_2_str].groupby('course_2_spring').count().empty:
        filled_course_2_spring = 0
    else:
        filled_course_2_spring = end_seminar[end_seminar['course_2_spring']==current_spring_2_str].groupby('course_2_spring').count().iloc[0]['id']
    num = num_student_cour_spring(current_spring_2_str) - filled_course_1_spring - filled_course_2_spring

    if num >0:
        # df_tmp для поиска вхождения текущего id во вторрую волну
        # df_tmp отфильтрован по spring_2 и отсортирован по percentile
        # определено количество оставшихся мест на курсе
        # учтены те кто вписал в spring_1 и spring_2 одно и тоже, у них с 1 волны стоит '???' в course_2_spring
        df_tmp = pd.concat([remain_students.loc[remain_students['spring_2']==current_spring_2_str],\
        remain_students[((remain_students['spring_2']==remain_students['course_1_spring']))\
        &(remain_students['spring_2']==current_spring_2_str)]]).drop_duplicates(keep=False).sort_values('percentile').head(num)

        if df_tmp.loc[df_tmp['id']==el].shape[0]==1: # Если теккущий id входит в df_tmp
            if pd.DataFrame(remain_students['num_course_spring'][remain_students['id']==el]).iloc[0]['num_course_spring']==2:
                course_2[el] = current_spring_2_str
            else: # num_course_spring==1
                course_1[el] = current_spring_2_str

# %%
for k, v in course_1.items():
    end_seminar.loc[end_seminar['id']==k, 'course_1_spring'] = v
for k, v in course_2.items():
    end_seminar.loc[end_seminar['id']==k, 'course_2_spring'] = v

# %%
end_seminar.loc[(end_seminar['course_1_spring']=='???')|(end_seminar['course_2_spring']=='???')].shape
# Out:
# (42, 24)

# %%
# Третья волна
# Исхожу из логики - стобец spring_3 полностью используется для заполнения '???'

remain_students = end_seminar.loc[(end_seminar['course_1_spring']=='???')\
                                  |(end_seminar['course_2_spring']=='???')]# таблица с незаполненными курсами
course_1 = dict()
course_2 = dict()

for el in remain_students['id']:
    # Имя курса №3 строкой для текущего id
    current_spring_3_str = pd.DataFrame(remain_students['spring_3'][remain_students['id']==el]).iloc[0]['spring_3']

    # количество оставшихся мест для зачисления на курс
    if end_seminar[end_seminar['course_1_spring']==current_spring_3_str].groupby('course_1_spring').count().empty:
        filled_course_1_spring = 0
    else:
        filled_course_1_spring = end_seminar[end_seminar['course_1_spring']==current_spring_3_str].groupby('course_1_spring').count().iloc[0]['id']
    if end_seminar[end_seminar['course_2_spring']==current_spring_3_str].groupby('course_2_spring').count().empty:
        filled_course_2_spring = 0
    else:
        filled_course_2_spring = end_seminar[end_seminar['course_2_spring']==current_spring_3_str].groupby('course_2_spring').count().iloc[0]['id']
    num = num_student_cour_spring(current_spring_2_str) - filled_course_1_spring - filled_course_2_spring

    if num >0:
        # df_tmp для поиска вхождения текущего id в третью волну
        # df_tmp отфильтрован по spring_3 и отсортирован по percentile
        # определено количество оставшихся мест на курсе
        # учтены те, кто вписал в spring_1, spring_2 и/или spring_3 одинаковые курсы, у них с 1 волны стоит '???' в course_2_spring если spring_1==spring_2
        # если spring_3 уже вписан в course_1_spring|course_2_spring его удалить из рассмотрения
        df_tmp = pd.concat([remain_students.loc[remain_students['spring_3']==current_spring_3_str],\
        remain_students[((remain_students['spring_3']==remain_students['course_1_spring'])|(remain_students['spring_3']==remain_students['course_2_spring']))\
        &(remain_students['spring_3']==current_spring_3_str)]]).drop_duplicates(keep=False).sort_values('percentile').head(num)

        if df_tmp.loc[df_tmp['id']==el].shape[0]==1:
            if pd.DataFrame(remain_students['num_course_spring'][remain_students['id']==el]).iloc[0]['num_course_spring']==2:
                if pd.DataFrame(remain_students['course_1_spring'][remain_students['id']==el]).iloc[0]['course_1_spring']=='???':
                    course_1[el] = current_spring_3_str
                else:
                    course_2[el] = current_spring_3_str
            else: # num_course_spring==1
                course_1[el] = current_spring_3_str

# %%
for k, v in course_1.items():
    end_seminar.loc[end_seminar['id']==k, 'course_1_spring'] = v
for k, v in course_2.items():
    end_seminar.loc[end_seminar['id']==k, 'course_2_spring'] = v

# %%
end_seminar.loc[(end_seminar['course_1_spring']=='???')|(end_seminar['course_2_spring']=='???')].shape
# Out:
# (26, 24)

# %%
end_seminar[['id', 'course_1_spring', 'course_2_spring']].to_csv('res_spring.csv', index=None)

# %% [markdown]
# **Отправьте свой файл res_spring.csv в контест (https://contest.yandex.ru/contest/19782/problems/B/) и прикрепите/укажите ниже ваш никнейм и ссылку на успешную посылку.**

# %% [markdown]
# На всякий случай просим вас сдать вместе с ноутбуком файл res_spring.csv в anytask

# %% [markdown]
# Вставьте картинку, описывающую ваш опыт выполнения этого задания:
